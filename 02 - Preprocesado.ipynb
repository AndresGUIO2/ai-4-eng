# %% [markdown]
# # Proyecto Modelos y Simulación de Sistemas I

# %%
import polars as pl

# %%
csv_file = "udea-ai-4-eng-20251-pruebas-saber-pro-colombia/train.csv"

# %% [markdown]
# ### Cargar el csv

# %%
train_df = pl.scan_csv(csv_file)

# %%
first_two_rows = train_df.head(2).collect()

display(first_two_rows)
# Out:
# shape: (2, 21)
# ┌────────┬─────────┬───────────────────┬───────────────────┬───┬────────┬────────┬────────┬────────┐
# │ ID     ┆ PERIODO ┆ ESTU_PRGM_ACADEMI ┆ ESTU_PRGM_DEPARTA ┆ … ┆ coef_1 ┆ coef_2 ┆ coef_3 ┆ coef_4 │
# │ ---    ┆ ---     ┆ CO                ┆ MENTO             ┆   ┆ ---    ┆ ---    ┆ ---    ┆ ---    │
# │ i64    ┆ i64     ┆ ---               ┆ ---               ┆   ┆ f64    ┆ f64    ┆ f64    ┆ f64    │
# │        ┆         ┆ str               ┆ str               ┆   ┆        ┆        ┆        ┆        │
# ╞════════╪═════════╪═══════════════════╪═══════════════════╪═══╪════════╪════════╪════════╪════════╡
# │ 904256 ┆ 20212   ┆ ENFERMERIA        ┆ BOGOTÁ            ┆ … ┆ 0.322  ┆ 0.208  ┆ 0.31   ┆ 0.267  │
# │ 645256 ┆ 20212   ┆ DERECHO           ┆ ATLANTICO         ┆ … ┆ 0.311  ┆ 0.215  ┆ 0.292  ┆ 0.264  │
# └────────┴─────────┴───────────────────┴───────────────────┴───┴────────┴────────┴────────┴────────┘

# %% [markdown]
# | Columna                      | Tipo de Variable      | Acción de Codificación                                                                                                                                   |
# |------------------------------|-----------------------|----------------------------------------------------------------------------------------------------------------------------------------------------------|
# | `RENDIMIENTO_GLOBAL`         | Ordinal (Target)      | Mapear a valores numéricos `0`–`3` según el orden (e.g., `"bajo": 0`, `"medio-bajo": 1`, `"medio-alto": 2`, `"alto": 3`)                                  |
# | `FAMI_ESTRATOVIVIENDA`       | Ordinal               | Mapear `"Estrato 1"`…`"Estrato 6"` a valores numéricos `1`…`6`                                                                                           |
# | `ESTU_HORASSEMANATRABAJA`    | Ordinal               | Mapear rangos de texto (e.g., `"0"`, `"Menos de 10 horas"`, etc.) a valores numéricos ordinales                                                          |
# | `FAMI_TIENEINTERNET`         | Categórica Binaria    | Convertir a `0` (No) / `1` (Si) y castear a `UInt8`                                                                                                      |
# | `FAMI_TIENELAVADORA`         | Categórica Binaria    | Convertir a `0` (No) / `1` (Si) y castear a `UInt8`                                                                                                      |
# | `FAMI_TIENEAUTOMOVIL`        | Categórica Binaria    | Convertir a `0` (No) / `1` (Si) y castear a `UInt8`                                                                                                      |
# | `ESTU_PRIVADO_LIBERTAD`      | Categórica Binaria    | Convertir a `0` (N) / `1` (S) y castear a `UInt8`                                                                                                        |
# | `ESTU_PAGOMATRICULAPROPIO`   | Categórica Binaria    | Convertir a `0` (No) / `1` (Si) y castear a `UInt8`                                                                                                      |
# | `FAMI_TIENECOMPUTADOR`       | Categórica Binaria    | Convertir a `0` (No) / `1` (Si) y castear a `UInt8`                                                                                                      |
# | `FAMI_TIENEINTERNET.1`       | Categórica Binaria    | Convertir a `0` (No) / `1` (Si) y castear a `UInt8` —  **Revisar si es columna duplicada**                                                                  |
# | `FAMI_EDUCACIONPADRE`        | Categórica Nominal    | Aplicar One-hot Encoding o Target Encoding                                                                                                               |
# | `FAMI_EDUCACIONMADRE`        | Categórica Nominal    | Aplicar One-hot Encoding o Target Encoding                                                                                                               |
# | `ESTU_PRGM_ACADEMICO`        | Categórica Nominal    | Aplicar One-hot Encoding o Target Encoding                                                                                                               |
# | `ESTU_PRGM_DEPARTAMENTO`     | Categórica Nominal    | Aplicar One-hot Encoding o Target Encoding                                                                                                               |
# | `coef_1` … `coef_4`          | Continua              | Mantener como `Float64`                                                                                                                                 |
# | Otras columnas (`ID`, `PERIODO`, etc.) | Variables de Identificación | No hacer nada por ahora                                                                                         |

# %% [markdown]
# ## Columnas Repetidas

# %% [markdown]
# Parece que la columna **FAMI_TIENEINTERNET** está repetida

# %%
equal_query = (
    train_df
    .select(
        #Seleccionar las columnas que se van a comparar
        (pl.col("FAMI_TIENEINTERNET") == pl.col("FAMI_TIENEINTERNET.1"))
        .all()
        .alias("equal_query")
    )
    .collect()
)

equal_query_result = equal_query["equal_query"][0]

print(f"Son todos los varlores 'FAMI_TIENEINTERNET' iguales a 'FAMI_TIENEINTERNET.1'? {equal_query_result}")
# Out:
# Son todos los varlores 'FAMI_TIENEINTERNET' iguales a 'FAMI_TIENEINTERNET.1'? True

# %% [markdown]
# Vemos que, como efectivamente **está repetida**, la podemos borrar.

# %%
train_df = train_df.drop("FAMI_TIENEINTERNET.1")

# %% [markdown]
# ## Estandarización

# %% [markdown]
# ### Ciudades

# %%
departments_count = (
    train_df
    .select(
        pl.col("ESTU_PRGM_DEPARTAMENTO")
          .n_unique()
          .alias("n_departamentos")
    )
    .collect()
)["n_departamentos"][0]
print(f"Hay {departments_count} departamentos distintos.")
# Out:
# Hay 31 departamentos distintos.

# %%
departaments = (
    train_df
    .select(
        pl.col("ESTU_PRGM_DEPARTAMENTO")
          .unique()
          .sort()
          .alias("departamentos")
    )
    .collect()
)["departamentos"]

# Convertimos la serie de departamentos a una lista
lista_departamentos = departaments.to_list()
print(f"{len(lista_departamentos)} departamentos encontrados:")
# Un salto de línea para mejor legibilidad
print("\n".join(lista_departamentos))
# Out:
# 31 departamentos encontrados:
# AMAZONAS
# ANTIOQUIA
# ARAUCA
# ATLANTICO
# BOGOTÁ
# BOLIVAR
# BOYACA
# CALDAS
# CAQUETA
# CASANARE
# CAUCA
# CESAR
# CHOCO
# CORDOBA
# CUNDINAMARCA
# GUAVIARE
# HUILA
# LA GUAJIRA
# MAGDALENA
# META
# NARIÑO
# NORTE SANTANDER
# PUTUMAYO
# QUINDIO
# RISARALDA
# SAN ANDRES
# SANTANDER
# SUCRE
# TOLIMA
# VALLE
# VAUPES

# %% [markdown]
# ### Programas

# %%
unique_programs = (
    train_df
    .select(
        pl.col("ESTU_PRGM_ACADEMICO")
          .str.replace(r'^"|"$', '', literal=False)           # quita comillas al inicio/final
          .str.replace(r'^\s+|\s+$', '', literal=False)  # quita espacios al inicio/final
          .str.to_uppercase()                                 
    )
    .unique()
    .sort("ESTU_PRGM_ACADEMICO")
    .collect()
    .get_column("ESTU_PRGM_ACADEMICO")
    .to_list()
)

# %% [markdown]
# #### Distancia de Levenshtein para Programas académicos

# %%
def levenshtein(a: str, b: str) -> int:
    if len(a) < len(b):
        a, b = b, a
    if not b:
        return len(a)
    prev = list(range(len(b) + 1))
    for i, ca in enumerate(a, start=1):
        curr = [i]
        for j, cb in enumerate(b, start=1):
            ins = prev[j] + 1
            rem = curr[j-1] + 1
            rep = prev[j-1] + (ca != cb)
            curr.append(min(ins, rem, rep))
        prev = curr
    return prev[-1]

# %%
threshold = 2
suggestions = []
n = len(unique_programs)
for i in range(n):
    for j in range(i+1, n):
        p1, p2 = unique_programs[i], unique_programs[j]
        d = levenshtein(p1.lower(), p2.lower())
        if d <= threshold:
            suggestions.append((p1, p2, d))

# %%
# Imprimimos las sugerencias de corrección
print(f"\nSugerencias de corrección (distancia <= {threshold}):")
for p1, p2, d in suggestions:
    print(f"{p1} <-> {p2} (distancia: {d})")
# Out:
# Sugerencias de corrección (distancia <= 2):
# ADMINISTRACION  FINANCIERA <-> ADMINISTRACION FINANCIERA (distancia: 1)
# ADMINISTRACION  FINANCIERA <-> ADMINISTRACIÓN FINANCIERA (distancia: 2)
# ADMINISTRACION COMERCIAL <-> ADMINISTRACIÓN COMERCIAL (distancia: 1)
# ADMINISTRACION DE COMERCIO EXTERIOR <-> ADMINISTRACIÓN DE COMERCIO EXTERIOR (distancia: 1)
# ADMINISTRACION DE EMPRESAS <-> ADMINISTRACI¿N DE EMPRESAS (distancia: 1)
# ADMINISTRACION DE EMPRESAS <-> ADMINISTRACIÓN DE EMPRESAS (distancia: 1)
# ADMINISTRACION DE EMPRESAS AGROINDUSTRIALES <-> ADMINISTRACIÓN DE EMPRESAS AGROINDUSTRIALES (distancia: 1)
# ADMINISTRACION DE EMPRESAS AGROPECUARIAS <-> ADMINISTRACIÓN DE EMPRESAS AGROPECUARIAS (distancia: 1)
# ADMINISTRACION DE EMPRESAS TURISTICA <-> ADMINISTRACION DE EMPRESAS TURISTICAS (distancia: 1)
# ADMINISTRACION DE EMPRESAS TURISTICA <-> ADMINISTRACIÓN DE EMPRESAS TURISTICAS (distancia: 2)
# ADMINISTRACION DE EMPRESAS TURISTICAS <-> ADMINISTRACIÓN DE EMPRESAS TURISTICAS (distancia: 1)
# ADMINISTRACION DE EMPRESAS TURISTICAS <-> ADMINISTRACIÓN DE EMPRESAS TURÍSTICAS (distancia: 2)
# ADMINISTRACION DE EMPRESAS TURISTICAS Y HOTELERAS <-> ADMINISTRACION DE EMPRESAS TURÍSTICAS Y HOTELERAS (distancia: 1)
# ADMINISTRACION DE EMPRESAS TURISTICAS Y HOTELERAS <-> ADMINISTRACIÓN DE EMPRESAS TURÍSTICAS Y HOTELERAS (distancia: 2)
# ADMINISTRACION DE EMPRESAS TURÍSTICAS Y HOTELERAS <-> ADMINISTRACIÓN DE EMPRESAS TURÍSTICAS Y HOTELERAS (distancia: 1)
# ADMINISTRACION DE MERCADEO Y LOGISTICA INTERNACIONALES <-> ADMINISTRACION EN MERCADEO Y LOGISTICA INTERNACIONALES (distancia: 2)
# ADMINISTRACION DE NEGOCIOS INTERNACIONALES <-> ADMINISTRACION EN NEGOCIOS INTERNACIONALES (distancia: 2)
# ADMINISTRACION DE NEGOCIOS INTERNACIONALES <-> ADMINISTRACION Y NEGOCIOS INTERNACIONALES (distancia: 2)
# ADMINISTRACION DE NEGOCIOS INTERNACIONALES <-> ADMINISTRACIÒN DE NEGOCIOS INTERNACIONALES (distancia: 1)
# ADMINISTRACION DE NEGOCIOS INTERNACIONALES <-> ADMINISTRACIÓN DE NEGOCIOS INTERNACIONALES (distancia: 1)
# ADMINISTRACION DE SERVICIOS DE SALUD <-> ADMINISTRACIÓN DE SERVICIOS DE SALUD (distancia: 1)
# ADMINISTRACION DE SISTEMAS INFORMATICOS <-> ADMINISTRACION DE SISTEMAS INFORMÁTICOS (distancia: 1)
# ADMINISTRACION EN NEGOCIOS INTERNACIONALES <-> ADMINISTRACION Y NEGOCIOS INTERNACIONALES (distancia: 2)
# ADMINISTRACION EN SALUD <-> ADMINISTRACIÓN EN SALUD (distancia: 1)
# ADMINISTRACION FINANCIERA <-> ADMINISTRACIÓN FINANCIERA (distancia: 1)
# ADMINISTRACION INFORMATICA <-> ADMINISTRACION INFORMÁTICA (distancia: 1)
# ADMINISTRACION LOGISTICA <-> ADMINISTRACI¿N LOG¿STICA (distancia: 2)
# ADMINISTRACION LOGISTICA <-> ADMINISTRACIÓN LOGISTICA (distancia: 1)
# ADMINISTRACION LOGISTICA <-> ADMINISTRACIÓN LOGÍSTICA (distancia: 2)
# ADMINISTRACION MARITIMA Y PORTUARIA <-> ADMINISTRACIÓN MARITIMA Y PORTUARIA (distancia: 1)
# ADMINISTRACION PUBLICA <-> ADMINISTRACI¿N P¿BLICA (distancia: 2)
# ADMINISTRACION PUBLICA <-> ADMINISTRACIÓN PÚBLICA (distancia: 2)
# ADMINISTRACION TECNOLOGICA <-> ADMINISTRACIÓN TECNÓLOGICA (distancia: 2)
# ADMINISTRACION TURISTICA <-> ADMINISTRACION TURÍSTICA (distancia: 1)
# ADMINISTRACION TURISTICA <-> ADMINISTRACIÓN TURÍSTICA (distancia: 2)
# ADMINISTRACION TURISTICA Y HOTELERA <-> ADMINISTRACIÓN TURÍSTICA Y HOTELERA (distancia: 2)
# ADMINISTRACION TURISTICA Y HOTELERA <-> ADMINSITRACION TURISTICA Y HOTELERA (distancia: 2)
# ADMINISTRACION TURÍSTICA <-> ADMINISTRACIÓN TURÍSTICA (distancia: 1)
# ADMINISTRACION TURÍSTICA <-> ADMINISTRACIÓN TÚRÍSTICA (distancia: 2)
# ADMINISTRACION Y NEGOCIOS INTERNACIONALES <-> ADMINISTRACIÓN Y NEGOCIOS INTERNACIONALES (distancia: 1)
# ADMINISTRACI¿N DE EMPRESAS <-> ADMINISTRACIÓN DE EMPRESAS (distancia: 1)
# ADMINISTRACI¿N LOG¿STICA <-> ADMINISTRACIÓN LOGISTICA (distancia: 2)
# ADMINISTRACI¿N LOG¿STICA <-> ADMINISTRACIÓN LOGÍSTICA (distancia: 2)
# ADMINISTRACI¿N P¿BLICA <-> ADMINISTRACIÓN PÚBLICA (distancia: 2)
# ADMINISTRACIÒN DE NEGOCIOS INTERNACIONALES <-> ADMINISTRACIÓN DE NEGOCIOS INTERNACIONALES (distancia: 1)
# ADMINISTRACIÓN DE EMPRESAS <-> ADMINSITRACIÓN DE EMPRESAS (distancia: 2)
# ADMINISTRACIÓN DE EMPRESAS TURISTICAS <-> ADMINISTRACIÓN DE EMPRESAS TURÍSTICAS (distancia: 1)
# ADMINISTRACIÓN DE NEGOCIOS INTERNACIONALES <-> ADMINISTRACIÓN Y NEGOCIOS INTERNACIONALES (distancia: 2)
# ADMINISTRACIÓN DE SERVICIOS DE SALUD <-> ADMINISTRACIÓN EN SERVICIOS DE SALUD (distancia: 2)
# ADMINISTRACIÓN LOGISTICA <-> ADMINISTRACIÓN LOGÍSTICA (distancia: 1)
# ADMINISTRACIÓN TURÍSTICA <-> ADMINISTRACIÓN TÚRÍSTICA (distancia: 1)
# AGRONOMIA <-> ASTRONOMIA (distancia: 2)
# ANTROPOLOGIA <-> ANTROPOLOGÍA (distancia: 1)
# ARTES ESCENICAS <-> ARTES ESCÉNICAS (distancia: 1)
# ARTES PLASTICAS <-> ARTES PLÁSTICAS (distancia: 1)
# ARTES PLASTICAS Y VISUALES <-> ARTES PLÁSTICAS Y VISUALES (distancia: 1)
# ASTRONOMIA <-> GASTRONOMIA (distancia: 1)
# ASTRONOMIA <-> GASTRONOMÍA (distancia: 2)
# BIOINGENIERIA <-> BIOINGENIERÍA (distancia: 1)
# BIOLOGIA <-> BIOLOGÍA (distancia: 1)
# BIOLOGIA <-> ECOLOGIA (distancia: 2)
# BIOLOGIA <-> GEOLOGIA (distancia: 2)
# BIOLOGIA <-> TEOLOGIA (distancia: 2)
# BIOLOGIA AMBIENTAL <-> BIOLOGÍA AMBIENTAL (distancia: 1)
# BIOLOGÍA <-> ECOLOGÍA (distancia: 2)
# BIOLOGÍA <-> GEOLOGÍA (distancia: 2)
# BIOLOGÍA <-> TEOLOGÍA (distancia: 2)
# CIENCIA DE LA INFORMACION - BIBLIOTECOLOGIA <-> CIENCIA DE LA INFORMACION Y BIBLIOTECOLOGIA (distancia: 1)
# CIENCIA POLITICA <-> CIENCIA POLÍTICA (distancia: 1)
# CIENCIA POLITICA <-> CIENCIAS POLITICAS (distancia: 2)
# CIENCIA POLITICA Y GOBIERNO <-> CIENCIA POLÍTICA Y GOBIERNO (distancia: 1)
# CIENCIA POLÍTICA <-> CIENCIAS POLÍTICAS (distancia: 2)
# CIENCIAS POLITICAS <-> CIENCIAS POLÍTICAS (distancia: 1)
# CINE Y TELEVISION <-> CINE Y TELEVISIÓN (distancia: 1)
# COMUNICACION <-> COMUNICACIONES (distancia: 2)
# COMUNICACION AUDIOVISUAL <-> COMUNICACIÓN AUDIOVISUAL (distancia: 1)
# COMUNICACION AUDIOVISUAL Y MULTIMEDIAL <-> COMUNICACION AUDIOVISUAL Y MULTIMEDIOS (distancia: 2)
# COMUNICACION PUBLICITARIA <-> COMUNICACIÓN PUBLICITARIA (distancia: 1)
# COMUNICACION SOCIAL <-> COMUNICACI¿N SOCIAL (distancia: 1)
# COMUNICACION SOCIAL <-> COMUNICACIÓN SOCIAL (distancia: 1)
# COMUNICACION SOCIAL  - PERIODISMO <-> COMUNICACION SOCIAL -  PERIODISMO (distancia: 2)
# COMUNICACION SOCIAL  - PERIODISMO <-> COMUNICACION SOCIAL - PERIODISMO (distancia: 1)
# COMUNICACION SOCIAL  - PERIODISMO <-> COMUNICACION SOCIAL Y PERIODISMO (distancia: 2)
# COMUNICACION SOCIAL  - PERIODISMO <-> COMUNICACION SOCIAL- PERIODISMO (distancia: 2)
# COMUNICACION SOCIAL  - PERIODISMO <-> COMUNICACIÓN SOCIAL - PERIODISMO (distancia: 2)
# COMUNICACION SOCIAL -  PERIODISMO <-> COMUNICACION SOCIAL - PERIODISMO (distancia: 1)
# COMUNICACION SOCIAL -  PERIODISMO <-> COMUNICACION SOCIAL Y PERIODISMO (distancia: 2)
# COMUNICACION SOCIAL -  PERIODISMO <-> COMUNICACION SOCIAL- PERIODISMO (distancia: 2)
# COMUNICACION SOCIAL -  PERIODISMO <-> COMUNICACIÓN SOCIAL - PERIODISMO (distancia: 2)
# COMUNICACION SOCIAL - PERIODISMO <-> COMUNICACION SOCIAL PERIODISMO (distancia: 2)
# COMUNICACION SOCIAL - PERIODISMO <-> COMUNICACION SOCIAL Y PERIODISMO (distancia: 1)
# COMUNICACION SOCIAL - PERIODISMO <-> COMUNICACION SOCIAL- PERIODISMO (distancia: 1)
# COMUNICACION SOCIAL - PERIODISMO <-> COMUNICACION SOCIAL-PERIODISMO (distancia: 2)
# COMUNICACION SOCIAL - PERIODISMO <-> COMUNICACION SOCIALY PERIODISMO (distancia: 2)
# COMUNICACION SOCIAL - PERIODISMO <-> COMUNICACI¿N SOCIAL Y PERIODISMO (distancia: 2)
# COMUNICACION SOCIAL - PERIODISMO <-> COMUNICACIÓN SOCIAL - PERIODISMO (distancia: 1)
# COMUNICACION SOCIAL - PERIODISMO <-> COMUNICACIÓN SOCIAL Y PERIODISMO (distancia: 2)
# COMUNICACION SOCIAL PERIODISMO <-> COMUNICACION SOCIAL Y PERIODISMO (distancia: 2)
# COMUNICACION SOCIAL PERIODISMO <-> COMUNICACION SOCIAL- PERIODISMO (distancia: 1)
# COMUNICACION SOCIAL PERIODISMO <-> COMUNICACION SOCIAL-PERIODISMO (distancia: 1)
# COMUNICACION SOCIAL PERIODISMO <-> COMUNICACION SOCIALY PERIODISMO (distancia: 1)
# COMUNICACION SOCIAL Y PERIODISMO <-> COMUNICACION SOCIAL- PERIODISMO (distancia: 2)
# COMUNICACION SOCIAL Y PERIODISMO <-> COMUNICACION SOCIALY PERIODISMO (distancia: 1)
# COMUNICACION SOCIAL Y PERIODISMO <-> COMUNICACI¿N SOCIAL Y PERIODISMO (distancia: 1)
# COMUNICACION SOCIAL Y PERIODISMO <-> COMUNICACIÓN SOCIAL - PERIODISMO (distancia: 2)
# COMUNICACION SOCIAL Y PERIODISMO <-> COMUNICACIÓN SOCIAL Y PERIODISMO (distancia: 1)
# COMUNICACION SOCIAL- PERIODISMO <-> COMUNICACION SOCIAL-PERIODISMO (distancia: 1)
# COMUNICACION SOCIAL- PERIODISMO <-> COMUNICACION SOCIALY PERIODISMO (distancia: 1)
# COMUNICACION SOCIAL- PERIODISMO <-> COMUNICACIÓN SOCIAL - PERIODISMO (distancia: 2)
# COMUNICACION SOCIAL-PERIODISMO <-> COMUNICACION SOCIALY PERIODISMO (distancia: 2)
# COMUNICACION SOCIALY PERIODISMO <-> COMUNICACI¿N SOCIAL Y PERIODISMO (distancia: 2)
# COMUNICACION SOCIALY PERIODISMO <-> COMUNICACIÓN SOCIAL Y PERIODISMO (distancia: 2)
# COMUNICACION VISUAL <-> COMUNICACI¿N VISUAL (distancia: 1)
# COMUNICACI¿N SOCIAL <-> COMUNICACIÓN SOCIAL (distancia: 1)
# COMUNICACI¿N SOCIAL Y PERIODISMO <-> COMUNICACIÓN SOCIAL - PERIODISMO (distancia: 2)
# COMUNICACI¿N SOCIAL Y PERIODISMO <-> COMUNICACIÓN SOCIAL Y PERIODISMO (distancia: 1)
# COMUNICACIÓN SOCIAL - PERIODISMO <-> COMUNICACIÓN SOCIAL Y PERIODISMO (distancia: 1)
# CONTADURIA PUBLICA <-> CONTADURIA P¿BLICA (distancia: 1)
# CONTADURIA PUBLICA <-> CONTADURIA PÚBLICA (distancia: 1)
# CONTADURIA PUBLICA <-> CONTADURÍA PUBLICA (distancia: 1)
# CONTADURIA PUBLICA <-> CONTADURÍA PÚBLICA (distancia: 2)
# CONTADURIA P¿BLICA <-> CONTADURIA PÚBLICA (distancia: 1)
# CONTADURIA P¿BLICA <-> CONTADURÍA PUBLICA (distancia: 2)
# CONTADURIA P¿BLICA <-> CONTADURÍA PÚBLICA (distancia: 2)
# CONTADURIA PÚBLICA <-> CONTADURÍA PUBLICA (distancia: 2)
# CONTADURIA PÚBLICA <-> CONTADURÍA PÚBLICA (distancia: 1)
# CONTADURIA PÚBLICA <-> CONTADURÍA PÚBLICA. (distancia: 2)
# CONTADURÍA PUBLICA <-> CONTADURÍA PÚBLICA (distancia: 1)
# CONTADURÍA PUBLICA <-> CONTADURÍA PÚBLICA. (distancia: 2)
# CONTADURÍA PÚBLICA <-> CONTADURÍA PÚBLICA. (distancia: 1)
# DEPORTE Y ACTIVIDAD FISICA <-> DEPORTE Y ACTIVIDADA FISICA (distancia: 1)
# DERECHO Y CIENCIAS POLITICAS <-> DERECHO Y CIENCIAS POLÍTICAS (distancia: 1)
# DISENO GRAFICO <-> DISEÑO GRAFICO (distancia: 1)
# DISENO GRAFICO <-> DISEÑO GRÀFICO (distancia: 2)
# DISENO GRAFICO <-> DISEÑO GRÁFICO (distancia: 2)
# DISE¿O CROSSMEDIA <-> DISEÑO CROSSMEDIA (distancia: 1)
# DISEÑO DE ESPACIOS - ESCENARIO <-> DISEÑO DE ESPACIOS Y ESCENARIOS (distancia: 2)
# DISEÑO DE MODA <-> DISEÑO DE MODAS (distancia: 1)
# DISEÑO GRAFICO <-> DISEÑO GRÀFICO (distancia: 1)
# DISEÑO GRAFICO <-> DISEÑO GRÁFICO (distancia: 1)
# DISEÑO GRÀFICO <-> DISEÑO GRÁFICO (distancia: 1)
# ECOLOGIA <-> ECOLOGÍA (distancia: 1)
# ECOLOGIA <-> ECONOMIA (distancia: 2)
# ECOLOGIA <-> GEOLOGIA (distancia: 2)
# ECOLOGIA <-> TEOLOGIA (distancia: 2)
# ECOLOGÍA <-> ECONOMÍA (distancia: 2)
# ECOLOGÍA <-> GEOLOGÍA (distancia: 2)
# ECOLOGÍA <-> TEOLOGÍA (distancia: 2)
# ECONOMIA <-> ECONOM¿A (distancia: 1)
# ECONOMIA <-> ECONOMÍA (distancia: 1)
# ECONOM¿A <-> ECONOMÍA (distancia: 1)
# ENFERMERIA <-> ENFERMERÍA (distancia: 1)
# ESTADISTICA <-> ESTADÍSTICA (distancia: 1)
# ESTUDIOS Y GESTION CULTURAL <-> ESTUDIOS Y GESTIÓN CULTURAL (distancia: 1)
# FILOSOFIA <-> FILOSOFÍA (distancia: 1)
# FILOSOFIA Y HUMANIDADES <-> FILOSOFÍA Y HUMANIDADES (distancia: 1)
# FISICA <-> FÍSICA (distancia: 1)
# FISICA <-> MUSICA (distancia: 2)
# FISICA <-> MÚSICA (distancia: 2)
# FÍSICA <-> MUSICA (distancia: 2)
# FÍSICA <-> MÚSICA (distancia: 2)
# GASTRONOMIA <-> GASTRONOMÍA (distancia: 1)
# GEOLOGIA <-> GEOLOG¿A (distancia: 1)
# GEOLOGIA <-> GEOLOGÍA (distancia: 1)
# GEOLOGIA <-> TEOLOGIA (distancia: 1)
# GEOLOGIA <-> TEOLOGÍA (distancia: 2)
# GEOLOG¿A <-> GEOLOGÍA (distancia: 1)
# GEOLOG¿A <-> TEOLOGIA (distancia: 2)
# GEOLOG¿A <-> TEOLOGÍA (distancia: 2)
# GEOLOGÍA <-> TEOLOGIA (distancia: 2)
# GEOLOGÍA <-> TEOLOGÍA (distancia: 1)
# GESTION EN ECOLOGIA Y TURISMO <-> GESTIÓN EN ECOLOGÍA Y TURISMO (distancia: 2)
# INGENIERIA  AGROFORESTAL <-> INGENIERIA AGROFORESTAL (distancia: 1)
# INGENIERIA  AMBIENTAL <-> INGENIERIA AMBIENTAL (distancia: 1)
# INGENIERIA  AMBIENTAL <-> INGENIERÍA AMBIENTAL (distancia: 2)
# INGENIERIA  CIVIL <-> INGENIERIA CIVIL (distancia: 1)
# INGENIERIA  CIVIL <-> INGENIERÍA CIVIL (distancia: 2)
# INGENIERIA AERONAUTICA <-> INGENIERÍA AERONÁUTICA (distancia: 2)
# INGENIERIA AGRICOLA <-> INGENIERÍA AGRÍCOLA (distancia: 2)
# INGENIERIA AGROECOLOGICA <-> INGENIERÍA AGROECOLÓGICA (distancia: 2)
# INGENIERIA AGROINDUSTRIAL <-> INGENIERÍA AGROINDUSTRIAL (distancia: 1)
# INGENIERIA AGRONOMICA <-> INGENIERIA AGRONÓMICA (distancia: 1)
# INGENIERIA AGRONOMICA <-> INGENIERÍA AGRONOMICA (distancia: 1)
# INGENIERIA AGRONOMICA <-> INGENIERÍA AGRONÓMICA (distancia: 2)
# INGENIERIA AGRONÓMICA <-> INGENIERÍA AGRONOMICA (distancia: 2)
# INGENIERIA AGRONÓMICA <-> INGENIERÍA AGRONÓMICA (distancia: 1)
# INGENIERIA AGROPECUARIA <-> INGENIERÍA AGROPECUARIA (distancia: 1)
# INGENIERIA AMBIENTAL <-> INGENIERÍA AMBIENTAL (distancia: 1)
# INGENIERIA AMBIENTAL Y SANITARIA <-> INGENIERÍA AMBIENTAL Y SANITARIA (distancia: 1)
# INGENIERIA BIOLOGICA <-> INGENIERIA GEOLOGICA (distancia: 2)
# INGENIERIA BIOMEDICA <-> INGENIERIA BIOMÉDICA (distancia: 1)
# INGENIERIA BIOMEDICA <-> INGENIERÍA BIOMÉDICA (distancia: 2)
# INGENIERIA BIOMÉDICA <-> INGENIERÍA BIOMÉDICA (distancia: 1)
# INGENIERIA CIVIL <-> INGENIERÍA CIVIL (distancia: 1)
# INGENIERIA DE ALIMENTOS <-> INGENIERÍA DE ALIMENTOS (distancia: 1)
# INGENIERIA DE CONTROL <-> INGENIERIA EN CONTROL (distancia: 2)
# INGENIERIA DE MATERIALES <-> INGENIERÍA DE MATERIALES (distancia: 1)
# INGENIERIA DE MINAS <-> INGENIERÍA DE MINAS (distancia: 1)
# INGENIERIA DE PETROLEOS <-> INGENIERÍA DE PETRÓLEOS (distancia: 2)
# INGENIERIA DE PRODUCCION <-> INGENIERÍA DE PRODUCCIÓN (distancia: 2)
# INGENIERIA DE SISTEMAS <-> INGENIER¿A DE SISTEMAS (distancia: 1)
# INGENIERIA DE SISTEMAS <-> INGENIERÍA DE SISTEMAS (distancia: 1)
# INGENIERIA DE SISTEMAS Y  COMPUTACION <-> INGENIERIA DE SISTEMAS Y COMPUTACION (distancia: 1)
# INGENIERIA DE SISTEMAS Y COMPUTACION <-> INGENIERÍA DE SISTEMAS Y COMPUTACIÓN (distancia: 2)
# INGENIERIA DE SOFTWARE <-> INGENIERIA EN SOFTWARE (distancia: 2)
# INGENIERIA DE SOFTWARE <-> INGENIERÍA DE SOFTWARE (distancia: 1)
# INGENIERIA DE SOFTWARE <-> INGENIIERIA DE SOFTWARE (distancia: 1)
# INGENIERIA DE TELECOMUNICACIONES <-> INGENIERIA EN TELECOMUNICACIONES (distancia: 2)
# INGENIERIA DE TELECOMUNICACIONES <-> INGENIERÍA DE TELECOMUNICACIONES (distancia: 1)
# INGENIERIA ELECTRICA <-> INGENIERIA ELECTRONICA (distancia: 2)
# INGENIERIA ELECTRICA <-> INGENIERIA ELÉCTRICA (distancia: 1)
# INGENIERIA ELECTRICA <-> INGENIER¿A EL¿CTRICA (distancia: 2)
# INGENIERIA ELECTRICA <-> INGENIERÍA ELÉCTRICA (distancia: 2)
# INGENIERIA ELECTROMECANICA <-> INGENIERÍA ELECTROMECÁNICA (distancia: 2)
# INGENIERIA ELECTRONICA <-> INGENIERÍA ELECTRÓNICA (distancia: 2)
# INGENIERIA ELECTRONICA Y TELECOMUNICACIONES <-> INGENIERÍA ELECTRÓNICA Y TELECOMUNICACIONES (distancia: 2)
# INGENIERIA ELÉCTRICA <-> INGENIER¿A EL¿CTRICA (distancia: 2)
# INGENIERIA ELÉCTRICA <-> INGENIERÍA ELÉCTRICA (distancia: 1)
# INGENIERIA EN  TELECOMUNICACIONES <-> INGENIERIA EN TELECOMUNICACIONES (distancia: 1)
# INGENIERIA EN AUTOMATIZACIÓN <-> INGENIERÍA EN AUTOMATIZACIÓN (distancia: 1)
# INGENIERIA EN DISEÑO INDUSTRIAL <-> INGENIERÍA EN DISEÑO INDUSTRIAL (distancia: 1)
# INGENIERIA EN ENERGIA <-> INGENIERIA EN ENERGIAS (distancia: 1)
# INGENIERIA EN ENERGIA <-> INGENIERÍA EN ENERGÍA (distancia: 2)
# INGENIERIA EN ENERGIAS <-> INGENIERÍA EN ENERGÍAS (distancia: 2)
# INGENIERIA EN INFORMATICA <-> INGENIERÍA EN INFORMÁTICA (distancia: 2)
# INGENIERIA EN SEGURIDAD Y SALUD PARA EL TRABAJO <-> INGENIERÍA EN SEGURIDAD Y SALUD PARA EL TRABAJO (distancia: 1)
# INGENIERIA EN SOFTWARE <-> INGENIER¿A EN SOFTWARE (distancia: 1)
# INGENIERIA EN TELEMATICA <-> INGENIERÍA EN TELEMÁTICA (distancia: 2)
# INGENIERIA FORESTAL <-> INGENIERÍA FORESTAL (distancia: 1)
# INGENIERIA GEOGRAFICA Y AMBIENTAL <-> INGENIERÍA GEOGRÁFICA Y AMBIENTAL (distancia: 2)
# INGENIERIA GEOLOGICA <-> INGENIERÍA GEOLÓGICA (distancia: 2)
# INGENIERIA INDUSTRIAL <-> INGENIER¿A INDUSTRIAL (distancia: 1)
# INGENIERIA INDUSTRIAL <-> INGENIERÍA INDUSTRIAL (distancia: 1)
# INGENIERIA INFORMATICA <-> INGENIERÌA INFORMÀTICA (distancia: 2)
# INGENIERIA INFORMATICA <-> INGENIERÍA INFORMÁTICA (distancia: 2)
# INGENIERIA MECANICA <-> INGENIERIA MECÁNICA (distancia: 1)
# INGENIERIA MECANICA <-> INGENIERÍA MECÁNICA (distancia: 2)
# INGENIERIA MECATRONICA <-> INGENIERIA MECATRONICO (distancia: 1)
# INGENIERIA MECATRONICA <-> INGENIERIA MECATRÓNICA (distancia: 1)
# INGENIERIA MECATRONICA <-> INGENIERÍA MECATRÓNICA (distancia: 2)
# INGENIERIA MECATRONICO <-> INGENIERIA MECATRÓNICA (distancia: 2)
# INGENIERIA MECATRÓNICA <-> INGENIERÍA MECATRÓNICA (distancia: 1)
# INGENIERIA MECÁNICA <-> INGENIERÍA MECÁNICA (distancia: 1)
# INGENIERIA MULTIMEDIA <-> INGENIERÍA MULTIMEDIA (distancia: 1)
# INGENIERIA NAVAL <-> INGENIERÍA NAVAL (distancia: 1)
# INGENIERIA QUIMICA <-> INGENIERÍA QUÍMICA (distancia: 2)
# INGENIERIA SANITARIA <-> INGENIERÍA SANITARIA (distancia: 1)
# INGENIERIA TELEMATICA <-> INGENIERIA TELEMÁTICA (distancia: 1)
# INGENIER¿A DE SISTEMAS <-> INGENIERÍA DE SISTEMAS (distancia: 1)
# INGENIER¿A EL¿CTRICA <-> INGENIERÍA ELÉCTRICA (distancia: 2)
# INGENIER¿A INDUSTRIAL <-> INGENIERÍA INDUSTRIAL (distancia: 1)
# INGENIERÌA INFORMÀTICA <-> INGENIERÍA INFORMÁTICA (distancia: 2)
# INGENIERÍA AGRONOMICA <-> INGENIERÍA AGRONÓMICA (distancia: 1)
# INGENIERÍA DE SOFTWARE <-> INGENIIERIA DE SOFTWARE (distancia: 2)
# INGENIERÍA EN ENERGÍA <-> INGENIERÍA EN ENERGÍAS (distancia: 1)
# INSTRUMENTACION QUIRURGICA <-> INTRUMENTACION QUIRURGICA (distancia: 1)
# INVESTIGACION CRIMINAL <-> INVESTIGACIÓN CRIMINAL (distancia: 1)
# LICENCIATURA  EN INGLES Y FRANCES <-> LICENCIATURA EN INGLES Y FRANCES (distancia: 1)
# LICENCIATURA  EN MATEMATICAS <-> LICENCIATURA EN MATEMATICAS (distancia: 1)
# LICENCIATURA  EN MATEMATICAS <-> LICENCIATURA EN MATEM¿TICAS (distancia: 2)
# LICENCIATURA  EN MATEMATICAS <-> LICENCIATURA EN MATEMÁTICAS (distancia: 2)
# LICENCIATURA  PEDAGOGIA INFANTIL <-> LICENCIATURA EN PEDAGOGIA INFANTIL (distancia: 2)
# LICENCIATURA EN  CIENCIAS NATURALES Y EDUCACION AMBIENTAL <-> LICENCIATURA EN CIENCIAS NATURALES Y EDUCACION AMBIENTAL (distancia: 1)
# LICENCIATURA EN  CIENCIAS NATURALES Y EDUCACION AMBIENTAL <-> LICENCIATURA EN CIENCIAS NATURALES Y EDUCACIÓN AMBIENTAL (distancia: 2)
# LICENCIATURA EN  FILOSOFIA <-> LICENCIATURA EN FILOSOFIA (distancia: 1)
# LICENCIATURA EN  FILOSOFIA <-> LICENCIATURA EN FILOSOFÍA (distancia: 2)
# LICENCIATURA EN  LITERATURA Y LENGUA CASTELLANA <-> LICENCIATURA EN LITERATURA Y LENGUA CASTELLANA (distancia: 1)
# LICENCIATURA EN  MATEMATICAS Y FISICA <-> LICENCIATURA EN MATEMATICAS Y FISICA (distancia: 1)
# LICENCIATURA EN ARTES ESCENICAS <-> LICENCIATURA EN ARTES ESC¿NICAS (distancia: 1)
# LICENCIATURA EN ARTES ESCENICAS <-> LICENCIATURA EN ARTES ESCÉNICAS (distancia: 1)
# LICENCIATURA EN ARTES ESC¿NICAS <-> LICENCIATURA EN ARTES ESCÉNICAS (distancia: 1)
# LICENCIATURA EN BIOLOGIA <-> LICENCIATURA EN BIOLOGÍA (distancia: 1)
# LICENCIATURA EN BIOLOGIA <-> LICENCIATURA EN TEOLOGIA (distancia: 2)
# LICENCIATURA EN BIOLOGÍA <-> LICENCIATURA EN TEOLOGÍA (distancia: 2)
# LICENCIATURA EN CIENCIAS NATURALES Y EDUCACION AMBIENTAL <-> LICENCIATURA EN CIENCIAS NATURALES Y EDUCACIÓN AMBIENTAL (distancia: 1)
# LICENCIATURA EN EDUCACION ARTISTICA <-> LICENCIATURA EN EDUCACI¿N ART¿STICA (distancia: 2)
# LICENCIATURA EN EDUCACION ARTISTICA <-> LICENCIATURA EN EDUCACIÓN ARTÍSTICA (distancia: 2)
# LICENCIATURA EN EDUCACION ARTISTICA Y CULTURAL <-> LICENCIATURA EN EDUCACIÓN ARTÍSTICA Y CULTURAL (distancia: 2)
# LICENCIATURA EN EDUCACION BASICA  CON ENFASIS EN HUMANIDADES Y LENGUA CASTELLANA <-> LICENCIATURA EN EDUCACION BASICA CON ENFASIS EN HUMANIDADES Y LENGUA CASTELLANA (distancia: 1)
# LICENCIATURA EN EDUCACION BASICA CON ENFASIS EN  HUMANIDADES, LENGUA CASTELLANA E INGLES <-> LICENCIATURA EN EDUCACION BASICA CON ENFASIS EN HUMANIDADES,LENGUA CASTELLANA E INGLES (distancia: 2)
# LICENCIATURA EN EDUCACION BASICA CON ENFASIS EN  HUMANIDADES, LENGUA CASTELLANA E INGLES <-> LICENCIATURA EN EDUCACION BASICA CON ENFASIS EN HUMANIDADES: LENGUA CASTELLANA E INGLES (distancia: 2)
# LICENCIATURA EN EDUCACION BASICA CON ENFASIS EN EDUCACION FISICA, RECREACION Y DEPORTES <-> LICENCIATURA EN EDUCACION BASICA CON ENFASIS EN EDUCACION FISICA,RECREACION Y DEPORTE (distancia: 2)
# LICENCIATURA EN EDUCACION BASICA CON ENFASIS EN EDUCACION FISICA, RECREACION Y DEPORTES <-> LICENCIATURA EN EDUCACION BASICA CON ENFASIS EN EDUCACION FISICA,RECREACION Y DEPORTES (distancia: 1)
# LICENCIATURA EN EDUCACION BASICA CON ENFASIS EN EDUCACION FISICA,RECREACION Y DEPORTE <-> LICENCIATURA EN EDUCACION BASICA CON ENFASIS EN EDUCACION FISICA,RECREACION Y DEPORTES (distancia: 1)
# LICENCIATURA EN EDUCACION BASICA CON ENFASIS EN HUMANIDADES -  LENGUA CASTELLANA <-> LICENCIATURA EN EDUCACION BASICA CON ENFASIS EN HUMANIDADES Y LENGUA CASTELLANA (distancia: 2)
# LICENCIATURA EN EDUCACION BASICA CON ENFASIS EN HUMANIDADES Y LENGUA CASTELLANA <-> LICENCIATURA EN EDUCACION BASICA CON ENFASIS EN HUMANIDADES, LENGUA CASTELLANA (distancia: 2)
# LICENCIATURA EN EDUCACION BASICA CON ENFASIS EN HUMANIDADES, LENGUA CASTELLANA <-> LICENCIATURA EN EDUCACION BASICA CON ENFASIS EN HUMANIDADES,LENGUA CASTELLANA (distancia: 1)
# LICENCIATURA EN EDUCACION BASICA CON ENFASIS EN HUMANIDADES,LENGUA CASTELLANA E INGLES <-> LICENCIATURA EN EDUCACION BASICA CON ENFASIS EN HUMANIDADES: LENGUA CASTELLANA E INGLES (distancia: 2)
# LICENCIATURA EN EDUCACION BASICA ENFASIS EN CIENCIAS NATURALES Y EDUCACION AMBIENTAL <-> LICENCIATURA EN EDUCACION BASICA, ENFASIS EN CIENCIAS NATURALES Y EDUCACION AMBIENTAL (distancia: 1)
# LICENCIATURA EN EDUCACION BASICA PRIMARIA <-> LICENCIATURA EN EDUCACI¿N B¿SICA PRIMARIA (distancia: 2)
# LICENCIATURA EN EDUCACION BASICA PRIMARIA <-> LICENCIATURA EN EDUCACIÓN BÁSICA PRIMARIA (distancia: 2)
# LICENCIATURA EN EDUCACION BILINGUE <-> LICENCIATURA EN EDUCACIÓN BILINGUE (distancia: 1)
# LICENCIATURA EN EDUCACION BÁSICA CON ÉNFASIS EN CIENCIAS NATURALES Y EDUCACIÓN AMBIENTAL <-> LICENCIATURA EN EDUCACIÓN BÁSICA CON ÉNFASIS EN CIENCIAS NATURALES Y EDUCACIÓN AMBIENTAL (distancia: 1)
# LICENCIATURA EN EDUCACION ESPECIAL <-> LICENCIATURA EN EDUCACIÓN ESPECIAL (distancia: 1)
# LICENCIATURA EN EDUCACION FISICA RECREACION Y DEPORTE <-> LICENCIATURA EN EDUCACION FISICA, RECREACION Y DEPORTE (distancia: 1)
# LICENCIATURA EN EDUCACION FISICA RECREACION Y DEPORTE <-> LICENCIATURA EN EDUCACION FISICA, RECREACION Y DEPORTES (distancia: 2)
# LICENCIATURA EN EDUCACION FISICA RECREACION Y DEPORTE <-> LICENCIATURA EN EDUCACION FISICA,RECREACION Y DEPORTE (distancia: 1)
# LICENCIATURA EN EDUCACION FISICA RECREACION Y DEPORTE <-> LICENCIATURA EN EDUCACION FISICA,RECREACION Y DEPORTES (distancia: 2)
# LICENCIATURA EN EDUCACION FISICA Y DEPORTES <-> LICENCIATURA EN EDUCACIÓN FÍSICA Y DEPORTES (distancia: 2)
# LICENCIATURA EN EDUCACION FISICA, RECREACION Y DEPORTE <-> LICENCIATURA EN EDUCACION FISICA, RECREACION Y DEPORTES (distancia: 1)
# LICENCIATURA EN EDUCACION FISICA, RECREACION Y DEPORTE <-> LICENCIATURA EN EDUCACION FISICA,RECREACION Y DEPORTE (distancia: 1)
# LICENCIATURA EN EDUCACION FISICA, RECREACION Y DEPORTE <-> LICENCIATURA EN EDUCACION FISICA,RECREACION Y DEPORTES (distancia: 2)
# LICENCIATURA EN EDUCACION FISICA, RECREACION Y DEPORTE <-> LICENCIATURA EN EDUCACON FISICA, RECREACION Y DEPORTES (distancia: 2)
# LICENCIATURA EN EDUCACION FISICA, RECREACION Y DEPORTES <-> LICENCIATURA EN EDUCACION FISICA,RECREACION Y DEPORTE (distancia: 2)
# LICENCIATURA EN EDUCACION FISICA, RECREACION Y DEPORTES <-> LICENCIATURA EN EDUCACION FISICA,RECREACION Y DEPORTES (distancia: 1)
# LICENCIATURA EN EDUCACION FISICA, RECREACION Y DEPORTES <-> LICENCIATURA EN EDUCACON FISICA, RECREACION Y DEPORTES (distancia: 1)
# LICENCIATURA EN EDUCACION FISICA,RECREACION Y DEPORTE <-> LICENCIATURA EN EDUCACION FISICA,RECREACION Y DEPORTES (distancia: 1)
# LICENCIATURA EN EDUCACION FISICA,RECREACION Y DEPORTES <-> LICENCIATURA EN EDUCACON FISICA, RECREACION Y DEPORTES (distancia: 2)
# LICENCIATURA EN EDUCACION INFANTIL <-> LICENCIATURA EN EDUCACI¿N INFANTIL (distancia: 1)
# LICENCIATURA EN EDUCACION INFANTIL <-> LICENCIATURA EN EDUCACIÓN INFANTIL (distancia: 1)
# LICENCIATURA EN EDUCACION PARA LA PRIMERA INFANCIA <-> LICENCIATURA EN EDUCACIÓN PARA LA PRIMERA INFANCIA (distancia: 1)
# LICENCIATURA EN EDUCACION PREESCOLAR <-> LICENCIATURA EN EDUCACIÓN PREESCOLAR (distancia: 1)
# LICENCIATURA EN EDUCACION: ARTES PLASTICAS <-> LICENCIATURA EN EDUCACIÓN: ARTES PLÁSTICAS (distancia: 2)
# LICENCIATURA EN EDUCACI¿N ART¿STICA <-> LICENCIATURA EN EDUCACIÓN ARTÍSTICA (distancia: 2)
# LICENCIATURA EN EDUCACI¿N B¿SICA PRIMARIA <-> LICENCIATURA EN EDUCACIÓN BÁSICA PRIMARIA (distancia: 2)
# LICENCIATURA EN EDUCACI¿N INFANTIL <-> LICENCIATURA EN EDUCACIÓN INFANTIL (distancia: 1)
# LICENCIATURA EN EDUCACIÓN  FÍSICA, RECREACIÓN Y DEPORTE <-> LICENCIATURA EN EDUCACIÓN  FÍSICA, RECREACIÓN Y DEPORTES (distancia: 1)
# LICENCIATURA EN EDUCACIÓN  FÍSICA, RECREACIÓN Y DEPORTE <-> LICENCIATURA EN EDUCACIÓN FÍSICA, RECREACIÓN Y DEPORTE (distancia: 1)
# LICENCIATURA EN EDUCACIÓN  FÍSICA, RECREACIÓN Y DEPORTES <-> LICENCIATURA EN EDUCACIÓN FÍSICA, RECREACIÓN Y DEPORTE (distancia: 2)
# LICENCIATURA EN EDUCACIÓN BÁSICA CON ÉNFASIS EN HUMANIDADES LENGUA CASTELLANA <-> LICENCIATURA EN EDUCACIÓN BÁSICA CON ÉNFASIS EN HUMANIDADES, LENGUA CASTELLANA (distancia: 1)
# LICENCIATURA EN EDUCACIÓN BÁSICA CON ÉNFASIS EN HUMANIDADES LENGUA CASTELLANA <-> LICENCIATURA EN EDUCACIÓN BÁSICA CON ÉNFASIS EN HUMANIDADES- LENGUA CASTELLANA (distancia: 1)
# LICENCIATURA EN EDUCACIÓN BÁSICA CON ÉNFASIS EN HUMANIDADES LENGUA CASTELLANA <-> LICENCIATURA EN EDUCACIÓN BÁSICA, CON ÉNFASIS EN HUMANIDADES, LENGUA CASTELLANA (distancia: 2)
# LICENCIATURA EN EDUCACIÓN BÁSICA CON ÉNFASIS EN HUMANIDADES, LENGUA CASTELLANA <-> LICENCIATURA EN EDUCACIÓN BÁSICA CON ÉNFASIS EN HUMANIDADES- LENGUA CASTELLANA (distancia: 1)
# LICENCIATURA EN EDUCACIÓN BÁSICA CON ÉNFASIS EN HUMANIDADES, LENGUA CASTELLANA <-> LICENCIATURA EN EDUCACIÓN BÁSICA, CON ÉNFASIS EN HUMANIDADES, LENGUA CASTELLANA (distancia: 1)
# LICENCIATURA EN EDUCACIÓN BÁSICA CON ÉNFASIS EN HUMANIDADES- LENGUA CASTELLANA <-> LICENCIATURA EN EDUCACIÓN BÁSICA, CON ÉNFASIS EN HUMANIDADES, LENGUA CASTELLANA (distancia: 2)
# LICENCIATURA EN EDUCACIÓN FÍSICA Y DEPORTE <-> LICENCIATURA EN EDUCACIÓN FÍSICA Y DEPORTES (distancia: 1)
# LICENCIATURA EN ESPAÑOL E INGLES <-> LICENCIATURA EN ESPAÑOL E INGLÉS (distancia: 1)
# LICENCIATURA EN FILOSOFIA <-> LICENCIATURA EN FILOSOFÍA (distancia: 1)
# LICENCIATURA EN FILOSOFIA Y HUMANIDADES <-> LICENCIATURA EN FILOSOF¿A Y HUMANIDADES (distancia: 1)
# LICENCIATURA EN FISICA <-> LICENCIATURA EN FÍSICA (distancia: 1)
# LICENCIATURA EN FISICA <-> LICENCIATURA EN MUSICA (distancia: 2)
# LICENCIATURA EN FISICA <-> LICENCIATURA EN MÚSICA (distancia: 2)
# LICENCIATURA EN FÍSICA <-> LICENCIATURA EN MUSICA (distancia: 2)
# LICENCIATURA EN FÍSICA <-> LICENCIATURA EN MÚSICA (distancia: 2)
# LICENCIATURA EN INGLES <-> LICENCIATURA EN INGLÉS (distancia: 1)
# LICENCIATURA EN LENGUAS  EXTRANJERAS <-> LICENCIATURA EN LENGUAS EXTRANJERAS (distancia: 1)
# LICENCIATURA EN LENGUAS EXTRANJERAS CON ENFASIS EN INGLES <-> LICENCIATURA EN LENGUAS EXTRANJERAS CON ¿NFASIS EN INGL¿S (distancia: 2)
# LICENCIATURA EN LENGUAS EXTRANJERAS CON ENFASIS EN INGLES <-> LICENCIATURA EN LENGUAS EXTRANJERAS CON ÉNFASIS EN INGLÉS (distancia: 2)
# LICENCIATURA EN LENGUAS EXTRANJERAS CON ¿NFASIS EN INGL¿S <-> LICENCIATURA EN LENGUAS EXTRANJERAS CON ÉNFASIS EN INGLÉS (distancia: 2)
# LICENCIATURA EN LENGUAS EXTRANJERAS INGLES - FRANCES <-> LICENCIATURA EN LENGUAS EXTRANJERAS INGLES-FRANCES (distancia: 2)
# LICENCIATURA EN LENGUAS EXTRANJERAS INGLES-FRANCES <-> LICENCIATURA EN LENGUAS EXTRANJERAS: INGLES-FRANCES (distancia: 1)
# LICENCIATURA EN MATEMATICAS <-> LICENCIATURA EN MATEM¿TICAS (distancia: 1)
# LICENCIATURA EN MATEMATICAS <-> LICENCIATURA EN MATEMÁTICAS (distancia: 1)
# LICENCIATURA EN MATEMATICAS Y FISICA <-> LICENCIATURA EN MATEMÁTICAS Y FÍSICA (distancia: 2)
# LICENCIATURA EN MATEM¿TICAS <-> LICENCIATURA EN MATEMÁTICAS (distancia: 1)
# LICENCIATURA EN MUSICA <-> LICENCIATURA EN MÚSICA (distancia: 1)
# LICENCIATURA EN PEDAGOGIA  INFANTIL <-> LICENCIATURA EN PEDAGOGIA INFANTIL (distancia: 1)
# LICENCIATURA EN PEDAGOGIA  INFANTIL <-> LICENCIATURA EN PEDAGOG¿A INFANTIL (distancia: 2)
# LICENCIATURA EN PEDAGOGIA  INFANTIL <-> LICENCIATURA EN PEDAGOGÍA INFANTIL (distancia: 2)
# LICENCIATURA EN PEDAGOGIA INFANTIL <-> LICENCIATURA EN PEDAGOG¿A INFANTIL (distancia: 1)
# LICENCIATURA EN PEDAGOGIA INFANTIL <-> LICENCIATURA EN PEDAGOGÍA INFANTIL (distancia: 1)
# LICENCIATURA EN PEDAGOG¿A INFANTIL <-> LICENCIATURA EN PEDAGOGÍA INFANTIL (distancia: 1)
# LICENCIATURA EN TECNOLOGIA E INFORMATICA <-> LICENCIATURA EN TECNOLOGÍA E INFORMÁTICA (distancia: 2)
# LICENCIATURA EN TEOLOGIA <-> LICENCIATURA EN TEOLOGÍA (distancia: 1)
# MAESTRO EN MUSICA <-> MAESTRO EN MÚSICA (distancia: 1)
# MATEMATICAS <-> MATEMÁTICAS (distancia: 1)
# MICROBIOLOGIA <-> MICROBIOLOGÍA (distancia: 1)
# MICROBIOLOGIA INDUSTRIAL Y AMBIENTAL <-> MICROBIOLOGÍA INDUSTRIAL Y AMBIENTAL (distancia: 1)
# MICROBIOLOGIA Y BIOANALISIS <-> MICROBIOLOGÍA Y BIOANÁLISIS (distancia: 2)
# MUSICA <-> MÚSICA (distancia: 1)
# MUSICA INSTRUMENTAL <-> MUSICA INSTRUMENTO (distancia: 2)
# NUTRICION Y DIETETICA <-> NUTRICIÓN Y DIETETICA (distancia: 1)
# NUTRICION Y DIETETICA <-> NUTRICIÓN Y DIETÉTICA (distancia: 2)
# NUTRICIÓN Y DIETETICA <-> NUTRICIÓN Y DIETÉTICA (distancia: 1)
# ODONTOLOGIA <-> ODONTOLOGÍA (distancia: 1)
# OPTOMETRIA <-> OPTOMETRÍA (distancia: 1)
# PROFESIONAL  EN DISEÑO GRAFICO <-> PROFESIONAL EN DISEÑO GRAFICO (distancia: 1)
# PROFESIONAL  EN DISEÑO GRAFICO <-> PROFESIONAL EN DISEÑO GRÁFICO (distancia: 2)
# PROFESIONAL EN  AGROINDUSTRIA <-> PROFESIONAL EN AGROINDUSTRIA (distancia: 1)
# PROFESIONAL EN ACTIVIDAD FISICA Y DEPORTE <-> PROFESIONAL EN ACTIVIDAD FÍSICA Y DEPORTE (distancia: 1)
# PROFESIONAL EN DISEÑO GRAFICO <-> PROFESIONAL EN DISEÑO GRÁFICO (distancia: 1)
# PROFESIONAL EN GASTRONOMIA <-> PROFESIONAL EN GASTRONOM¿A (distancia: 1)
# PROFESIONAL EN GASTRONOMIA <-> PROFESIONAL EN GASTRONOMÍA (distancia: 1)
# PROFESIONAL EN GASTRONOM¿A <-> PROFESIONAL EN GASTRONOMÍA (distancia: 1)
# PSICOLOGIA <-> PSICOLOGÍA (distancia: 1)
# PSICOLOGIA <-> PSICÓLOGA (distancia: 2)
# PSICOLOGÍA <-> PSICÓLOGA (distancia: 2)
# QUIMICA <-> QUIMICA. (distancia: 1)
# QUIMICA <-> QUÍMICA (distancia: 1)
# QUIMICA FARMACEUTICA <-> QU¿MICA FARMAC¿UTICA (distancia: 2)
# QUIMICA FARMACEUTICA <-> QUÍMICA FARMACÉUTICA (distancia: 2)
# QUIMICA INDUSTRIAL <-> QUÍMICA INDUSTRIAL (distancia: 1)
# QUIMICA. <-> QUÍMICA (distancia: 2)
# QU¿MICA FARMAC¿UTICA <-> QUÍMICA FARMACÉUTICA (distancia: 2)
# SOCIOLOGIA <-> SOCIOLOGÍA (distancia: 1)
# TEOLOGIA <-> TEOLOGÍA (distancia: 1)

# %% [markdown]
# Evidenciamos que los principales problemas son con tildes y espacios intermedios. Vamos a eliminarlos

# %%
accent_map = {
    "á": "a", "é": "e", "í": "i", "ó": "o", "ú": "u",
    "Á": "A", "É": "E", "Í": "I", "Ó": "O", "Ú": "U",
    "ñ": "n", "Ñ": "N"
}

# Construimos la expresión de normalización
expr = (
    pl.col("ESTU_PRGM_ACADEMICO")
      # 1) quitar comillas
      .str.replace_all('"', '', literal=True)
      # 2) pasar a mayúsculas
      .str.to_uppercase()
)

# 3) encadenar remap de cada tilde
for orig, repl in accent_map.items():
    expr = expr.str.replace_all(orig, repl, literal=True)
"
# 4) eliminar cualquier carácter que no sea A–Z, dígitos o espacio
expr = expr.str.replace_all(r'[^A-Z0-9 ]', '', literal=False)

# 5) colapsar múltiples espacios
expr = expr.str.replace_all(r'\s{2,}', ' ', literal=False)

# 6) quitar espacios al inicio/fin
expr = expr.str.replace_all(r'^\s+|\s+$', '', literal=False)

# Renombramos
expr = expr.alias("prog_norm")

# Ejecutamos lazy y obtenemos la lista limpia:
normalized_programs = (
    train_df
    .select(expr)
    .unique()
    .sort("prog_norm")
    .collect()
    .get_column("prog_norm")
    .to_list()
)

print(f"{len(normalized_programs)} programas normalizados:")
print(normalized_programs[:20], "…")
# Out:
# 752 programas normalizados:
# ['3 CICLO PROFESIONAL NEGOCIOS INTERNACIONALES', 'ACTIVIDAD FISICA Y DEPORTE', 'ACUICULTURA', 'ADMINISTRACIN DE EMPRESAS', 'ADMINISTRACIN DE NEGOCIOS INTERNACIONALES', 'ADMINISTRACIN LOGSTICA', 'ADMINISTRACIN PBLICA', 'ADMINISTRACION', 'ADMINISTRACION AERONAUTICA', 'ADMINISTRACION AGROINDUSTRIAL', 'ADMINISTRACION AGROPECUARIA', 'ADMINISTRACION AMBIENTAL', 'ADMINISTRACION AMBIENTAL Y DE LOS RECURSOS NATURALES', 'ADMINISTRACION BANCARIA Y FINANCIERA', 'ADMINISTRACION COMERCIAL', 'ADMINISTRACION COMERCIAL Y DE MERCADEO', 'ADMINISTRACION COMERCIAL Y FINANCIERA', 'ADMINISTRACION DE AGRONEGOCIOS', 'ADMINISTRACION DE COMERCIO EXTERIOR', 'ADMINISTRACION DE EMPRESAS'] …

# %% [markdown]
# ## Normalización de columnas Tipo Texto
